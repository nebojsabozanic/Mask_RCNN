# %%
# !ls
# %cd drive
# %cd Shared\ drives
# %cd Mask-RCNN
# Out:
# 'My Drive'  'Shared drives'
# [Errno 2] No such file or directory: 'drive'
# /content/drive
# /content/drive/Shared drives
# /content/drive/Shared drives/Mask-RCNN
# assets	   images   MANIFEST.in  README.md	   samples    setup.py
# cmd.ipynb  LICENSE  mrcnn	 requirements.txt  setup.cfg

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/Shared drives/Mask-RCNN/.git/

# %%
# !git config --global user.email "strance@gmail.com"
# !git config --global user.name "neboza"
# !git add .
# !git commit -m "first commit"
#!git push
# Out:
# fatal: Unable to create '/content/drive/Shared drives/Mask-RCNN/.git/index.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
# fatal: Unable to create '/content/drive/Shared drives/Mask-RCNN/.git/index.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
