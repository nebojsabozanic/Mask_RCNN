# %%
# !ls
# %cd drive
# %cd Shared\ drives
# %cd Mask-RCNN
# Out:
# drive  sample_data
# /content/drive
# /content/drive/Shared drives
# /content/drive/Shared drives/Mask-RCNN

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/Shared drives/Mask-RCNN/.git/

# %%
# !git config --global user.email "strance@gmail.com"
# !git config --global user.name "neboza"
# !git add .
# !git commit -m "first commit"
#!git push
# Out:
# [master f5e018c] first commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite cmd.ipynb (95%)

# %%
# !git remote add origin https://nebojsabozanic:sifrasifrasifrasifragithub@github.com/nebojsabozanic/Mask_RCNN.git

# %%
# !git push -u origin master
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://nebojsabozanic:sifrasifrasifrasifragithub@github.com/nebojsabozanic/Mask_RCNN.git/'

# %%
# !git remote rm origin
