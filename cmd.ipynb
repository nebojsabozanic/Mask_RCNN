# %%
# !ls
# %cd drive
# %cd Shared\ drives
# %cd Mask-RCNN
# Out:
# 'My Drive'  'Shared drives'
# [Errno 2] No such file or directory: 'drive'
# /content/drive
# /content/drive/Shared drives
# /content/drive/Shared drives/Mask-RCNN
# assets	   images   MANIFEST.in  README.md	   samples    setup.py
# cmd.ipynb  LICENSE  mrcnn	 requirements.txt  setup.cfg

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/Shared drives/Mask-RCNN/.git/

# %%
# !git config --global user.email "strance@gmail.com"
# !git config --global user.name "neboza"
# !git add .
# !git commit -m "first commit"
#!git push
# Out:
# [master (root-commit) 146635c] first commit
#  77 files changed, 15290 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 LICENSE
#  create mode 100644 MANIFEST.in
#  create mode 100644 README.md
#  create mode 100644 assets/4k_video.gif
#  create mode 100644 assets/balloon_color_splash.gif
#  create mode 100644 assets/detection_activations.png
#  create mode 100644 assets/detection_anchors.png
#  create mode 100644 assets/detection_final.png
#  create mode 100644 assets/detection_histograms.png
#  create mode 100644 assets/detection_masks.png
#  create mode 100644 assets/detection_refinement.png
#  create mode 100644 assets/detection_tensorboard.png
#  create mode 100644 assets/images_to_osm.png
#  create mode 100644 assets/mapping_challenge.png
#  create mode 100644 assets/nucleus_segmentation.png
#  create mode 100644 assets/project_3dbuildings.png
#  create mode 100644 assets/project_grass_gis.png
#  create mode 100644 assets/project_ice_wedge_polygons.png
#  create mode 100644 assets/project_shiny1.jpg
#  create mode 100644 assets/project_usiigaci1.gif
#  create mode 100644 assets/project_usiigaci2.gif
#  create mode 100644 assets/street.png
#  create mode 100644 cmd.ipynb
#  create mode 100644 images/1045023827_4ec3e8ba5c_z.jpg
#  create mode 100644 images/12283150_12d37e6389_z.jpg
#  create mode 100644 images/2383514521_1fc8d7b0de_z.jpg
#  create mode 100644 images/2502287818_41e4b0c4fb_z.jpg
#  create mode 100644 images/2516944023_d00345997d_z.jpg
#  create mode 100644 images/25691390_f9944f61b5_z.jpg
#  create mode 100644 images/262985539_1709e54576_z.jpg
#  create mode 100644 images/3132016470_c27baa00e8_z.jpg
#  create mode 100644 images/3627527276_6fe8cd9bfe_z.jpg
#  create mode 100644 images/3651581213_f81963d1dd_z.jpg
#  create mode 100644 images/3800883468_12af3c0b50_z.jpg
#  create mode 100644 images/3862500489_6fd195d183_z.jpg
#  create mode 100644 images/3878153025_8fde829928_z.jpg
#  create mode 100644 images/4410436637_7b0ca36ee7_z.jpg
#  create mode 100644 images/4782628554_668bc31826_z.jpg
#  create mode 100644 images/5951960966_d4e1cda5d0_z.jpg
#  create mode 100644 images/6584515005_fce9cec486_z.jpg
#  create mode 100644 images/6821351586_59aa0dc110_z.jpg
#  create mode 100644 images/7581246086_cf7bbb7255_z.jpg
#  create mode 100644 images/7933423348_c30bd9bd4e_z.jpg
#  create mode 100644 images/8053677163_d4c8f416be_z.jpg
#  create mode 100644 images/8239308689_efa6c11b08_z.jpg
#  create mode 100644 images/8433365521_9252889f9a_z.jpg
#  create mode 100644 images/8512296263_5fc5458e20_z.jpg
#  create mode 100644 images/8699757338_c3941051b6_z.jpg
#  create mode 100644 images/8734543718_37f6b8bd45_z.jpg
#  create mode 100644 images/8829708882_48f263491e_z.jpg
#  create mode 100644 images/9118579087_f9ffa19e63_z.jpg
#  create mode 100644 images/9247489789_132c0d534a_z.jpg
#  create mode 100644 mrcnn/__init__.py
#  create mode 100644 mrcnn/config.py
#  create mode 100644 mrcnn/model.py
#  create mode 100644 mrcnn/parallel_model.py
#  create mode 100644 mrcnn/utils.py
#  create mode 100644 mrcnn/visualize.py
#  create mode 100644 requirements.txt
#  create mode 100644 samples/balloon/README.md
#  create mode 100644 samples/balloon/balloon.py
#  create mode 100644 samples/balloon/inspect_balloon_data.ipynb
#  create mode 100644 samples/balloon/inspect_balloon_model.ipynb
#  create mode 100644 samples/coco/coco.py
#  create mode 100644 samples/coco/inspect_data.ipynb
#  create mode 100644 samples/coco/inspect_model.ipynb
#  create mode 100644 samples/coco/inspect_weights.ipynb
#  create mode 100644 samples/demo.ipynb
#  create mode 100644 samples/nucleus/README.md
#  create mode 100644 samples/nucleus/inspect_nucleus_data.ipynb
#  create mode 100644 samples/nucleus/inspect_nucleus_model.ipynb
#  create mode 100644 samples/nucleus/nucleus.py
#  create mode 100644 samples/shapes/shapes.py
#  create mode 100644 samples/shapes/train_shapes.ipynb
#  create mode 100644 setup.cfg
#  create mode 100644 setup.py

# %%
# !git remote add origin https://<nebojsabozanic>:<sifrasifrasifrasifra>github@github.com/<nebojsabozanic>/Mask_RCNN.git
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# /bin/bash: nebojsabozanic: Transport endpoint is not connected

# %%
# !git push -u origin master
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://nebojsabozanic:sifrasifrasifrasifragithub@github.com/nebojsabozanic/Mask_RCNN.git/'
